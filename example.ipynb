# %%
from log_batch import logBatch

path = './sample_data/KS_examples/'
logs = logBatch(path)
# Out:
# WARNING:root:Could not read the file: ./sample_data/KS_examples/1051325728.las
# WARNING:root:'No ~ sections found. Is this a LAS file?'
# WARNING:root:Could not read the file: ./sample_data/KS_examples/1051662829.las
# WARNING:root:'No ~ sections found. Is this a LAS file?'
# WARNING:root:Could not read the file: ./sample_data/KS_examples/1051662838.las
# WARNING:root:'No ~ sections found. Is this a LAS file?'

# %%
logs.df
# Out:
#                                          file    DEPT           CAL    GR  \
# 0    ./sample_data/KS_examples/1051325649.las  [DEPT]        [CALI]  [GR]
# 1    ./sample_data/KS_examples/1051325671.las  [DEPT]  [DCAL, MCAL]  [GR]
# 2    ./sample_data/KS_examples/1051325736.las  [DEPT]        [DCAL]  [GR]
# 3    ./sample_data/KS_examples/1051325746.las  [DEPT]           NaN  [GR]
# 4    ./sample_data/KS_examples/1051325747.las  [DEPT]        [DCAL]  [GR]
# ..                                        ...     ...           ...   ...
# 531  ./sample_data/KS_examples/1051712402.las  [DEPT]        [MCAL]  [GR]
# 532  ./sample_data/KS_examples/1051712408.las  [DEPT]        [MCAL]  [GR]
# 533  ./sample_data/KS_examples/1051712414.las  [DEPT]  [DCAL, MCAL]  [GR]
# 534  ./sample_data/KS_examples/1051712424.las  [DEPT]  [DCAL, MCAL]  [GR]
# 535  ./sample_data/KS_examples/1051712437.las  [DEPT]  [DCAL, MCAL]  [GR]
#
#         DEN     NEU               RES        DTC  DTS    SP   PEF
# ...

# %%
list_of_logs = ['DEPT', 'GR', 'RES', 'DTC']  
logs.filter(list_of_logs, inplace=True)
# Out:
# C:\Users\Naser.Tamimi\Desktop\my_codes_shell\log_batch\log_batch.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self.df[['file']+list_of_logs].dropna(inplace=inplace)
